# %% [markdown]
# <a href="https://colab.research.google.com/github/VamsiKavety/DataScience/blob/PyTutorials/1_variables_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 align="center" style="color:blue">Codebasics Python Course: Variables</h2>

# %% [markdown]
# ### Variables Introduction: String, Numbers, Boolean

# %% [markdown]
# Variables are containers that store some type of data. For example soda can is a container that contains soda

# %%
can = "soda"
can
# Out:
# 'soda'

# %%
print(can)
# Out:
# soda

# %%
can = "beans"
can
# Out:
# 'beans'

# %%
type(can)
# Out:
# str

# %%
pizza = 100
pizza
# Out:
# 100

# %%
type(pizza)
# Out:
# int

# %%
samosa=20.5
ice_cream=100

# %%
total = pizza + samosa + ice_cream
total
# Out:
# 220.5

# %%
type(total)
# Out:
# float

# %%
above_thresold = total > 200
above_thresold
# Out:
# True

# %%
type(above_thresold)
# Out:
# bool

# %% [markdown]
# **Integer** is a whole number with no decimal point. e.g. 34, 12, 500
#
# **Float** is a number with decimal point. e.g. 1.34, 0.45, 100.5
#
# **String** data types store text information
#
# **Boolean** type is used to store true or false value
#
#
# C, Java are Strongly Typed Languages ; buy Python is flexible

# %% [markdown]
# ### Everything is an Object in Python

# %%
foo = 'jalebi'
foo
# Out:
# 'jalebi'

# %%
bar = foo
bar
# Out:
# 'jalebi'

# %%
id(foo)
# Out:
# 132594835750448

# %%
id(bar)
# Out:
# 132594835750448

# %%
bar = 'samosa'
bar
# Out:
# 'samosa'

# %%
id(bar)
# Out:
# 132594835743792

# %%
foo
# Out:
# 'jalebi'

# %% [markdown]
# ### Variable Naming Rules

# %% [markdown]
# #### 1. Can't use reserved keywords to store variable names

# %%
True=5
# Out:
#   File "<ipython-input-26-4b271fdd8163>", line 1
#     True=5
#     ^
# SyntaxError: cannot assign to True

# %%
def = "Hello"

# %% [markdown]
# #### 2. Special characters are not allowed

# %%
$name="dhaval"

# %%
pizza^ = 100

# %% [markdown]
# #### 3. Variable names must begin with letter or _

# %%
4you="me"

# %%
$address="blah"

# %% [markdown]
# #### 4. Remaining characters should be a to z OR A to Z OR 0 to 9 OR _

# %%
abc$xyz=6

# %% [markdown]
# 💡 **Tip: Use Mr. C (i.e. ChatGPT) for help**
